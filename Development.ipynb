# %%
verify.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-538db673ccc5> in <module>
# ----> 1 verify.py
#
# NameError: name 'verify' is not defined
